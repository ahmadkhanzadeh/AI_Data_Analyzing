# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime, timedelta
import time

def scrape_wg_gesucht(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching the page: {e}")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    listings = []
    
    # Find all listing cards
    cards = soup.find_all('div', class_='card_body')
    
    for card in cards:
        listing = {}
        
        # 1. Title
        title_tag = card.find('h3', class_='truncate_title')
        listing['title'] = title_tag.get_text(strip=True) if title_tag else "N/A"
        
        # 2. Status and location information
        status_location_tag = card.find('div', class_='col-xs-11')
        if status_location_tag:
            status_location_text = status_location_tag.get_text(strip=True)
            parts = [part.strip() for part in status_location_text.split('|')]
            
            # 2. Status
            listing['status'] = parts[0] if len(parts) > 0 else "N/A"
            
            # 3. Location in city
            listing['location_in_city'] = parts[1] if len(parts) > 1 else "N/A"
            
            # 4. Location street
            listing['location_street'] = parts[2] if len(parts) > 2 else "N/A"
        
        # 5. Price, 6. Size, 7-8. Duration
        middle_row = card.find('div', class_='middle')
        if middle_row:
            cols = middle_row.find_all('div', class_=re.compile('col-xs-'))
            
            # 5. Price
            if len(cols) > 0:
                price_text = cols[0].get_text(strip=True)
                listing['price'] = price_text if price_text else "N/A"
            
            # 7-8. Duration
            if len(cols) > 1:
                duration_text = cols[1].get_text(strip=True)
                if ' - ' in duration_text:
                    from_to = duration_text.split(' - ')
                    listing['duration_from'] = from_to[0] if from_to[0] else "N/A"
                    listing['duration_to'] = from_to[1] if len(from_to) > 1 and from_to[1] else "N/A"
                else:
                    listing['duration_from'] = duration_text
                    listing['duration_to'] = "N/A"
            
            # 6. Size
            if len(cols) > 2:
                size_text = cols[2].get_text(strip=True)
                listing['size'] = size_text if size_text else "N/A"
        
        # 9. Advertisement time and 10. Provider
        bottom_row = card.find('div', class_='bottom')
        if bottom_row:
            # 10. Provider name
            provider_tag = bottom_row.find('span', class_='ml5')
            listing['provider'] = provider_tag.get_text(strip=True) if provider_tag else "N/A"
            
            # Check for verified company
            verified_tag = bottom_row.find('a', class_='label_verified')
            if verified_tag:
                listing['provider'] += " (Verified company)"
            
            # 9. Advertisement time
            time_tag = bottom_row.find('span', style='color: #218700;')
            if time_tag:
                time_text = time_tag.get_text(strip=True)
                if 'Online:' in time_text:
                    time_ago_text = time_text.replace('Online:', '').strip()
                    listing['advertisement_time'] = calculate_minutes_ago(time_ago_text)
                else:
                    listing['advertisement_time'] = 0
            else:
                listing['advertisement_time'] = 0
        
        listings.append(listing)
    
    return listings

def calculate_minutes_ago(time_text):
    now = datetime.now()
    
    if 'minute' in time_text:
        minutes = int(re.search(r'\d+', time_text).group())
        return minutes
    elif 'hour' in time_text:
        hours = int(re.search(r'\d+', time_text).group())
        return hours * 60
    elif 'day' in time_text:
        days = int(re.search(r'\d+', time_text).group())
        return days * 24 * 60
    elif 'currently' in time_text.lower() or 'jetzt' in time_text.lower():
        return 0
    else:
        return 0

if __name__ == "__main__":
    url = "https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Berlin.8.1.1.0.html"
    listings = scrape_wg_gesucht(url)
    
    for idx, listing in enumerate(listings, 1):
        print(f"\nListing #{idx}:")
        print(f"Title: {listing.get('title', 'N/A')}")
        print(f"Status: {listing.get('status', 'N/A')}")
        print(f"Location in city: {listing.get('location_in_city', 'N/A')}")
        print(f"Location street: {listing.get('location_street', 'N/A')}")
        print(f"Price: {listing.get('price', 'N/A')}")
        print(f"Size: {listing.get('size', 'N/A')}")
        print(f"Available from: {listing.get('duration_from', 'N/A')}")
        print(f"Available to: {listing.get('duration_to', 'N/A')}")
        print(f"Advertisement time (minutes ago): {listing.get('advertisement_time', 'N/A')}")
        print(f"Provider: {listing.get('provider', 'N/A')}")
# Out:
# Listing #1:
# Title: Modern designtes Studio-Apartment zu vermieten - Internationals welcome
# Status: N/A
# Location in city: N/A
# Location street: N/A
# Price: ab540 €
# Size: N/A
# Available from: kurzfristig frei
# Available to: N/A
# Advertisement time (minutes ago): N/A
# Provider: N/A
#
# Listing #2:
# Title: Tolles Studio-Apartment im Studentenwohnheim zu vermieten
# Status: N/A
# Location in city: N/A
# Location street: N/A
# Price: ab500 €
# Size: N/A
# Available from: kurzfristig frei
# Available to: N/A
# Advertisement time (minutes ago): N/A
# Provider: N/A
#
# Listing #3:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 14
# Price: 895 €
# Size: 16 m²
# Available from: 07.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #4:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 13
# Price: 895 €
# Size: 45 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #5:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 13
# Price: 895 €
# Size: 45 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #6:
# Title: STACEY Apartments Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 15
# Price: 895 €
# Size: 36 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #7:
# Title: Sonniges Studio mit privater Terrasse direkt am Mauerpark – zentral & möbliert im Studio House Berlin
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Gesundbrunnen
# Location street: Bärbel-Bohley-Ring 26
# Price: 990 €
# Size: 23 m²
# Available from: 07.04.2025
#
#
# Available to: 31.03.2027
# Advertisement time (minutes ago): 0
# Provider: Frau Gomez
#
# Listing #8:
# Title: 30 qm Studio in Shoneweide - NUR im Dezember
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Bohnsdorf
# Location street: Fließstraße
# Price: 600 €
# Size: 30 m²
# Available from: 09.08.2024
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: Wunderflats GmbH (Verified company)
#
# Listing #9:
# Title: Moderner Komfort trifft künstlerischen Charme – stilvolle 1-Zimmer-Wohnung mit Altbau Flair in Prenzlauer Berg
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Seelower Stra?e 10439 Berlin
# Location street: Krossener Straße
# Price: 1200 €
# Size: 36 m²
# Available from: 07.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: Sherry Mclemore
#
# Listing #10:
# Title: Großes 1-Zimmer-Küche-Bad Souterrain Apartment in Kleinmachnow
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Kleinmachnow
# Location street: Grasweg
# Price: 690 €
# Size: 55 m²
# Available from: 16.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: Frau Huang
#
# Listing #11:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 15
# Price: 895 €
# Size: 26 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #12:
# Title: Zugriff auf alle Anzeigen mit WG-Gesucht+
# Status: Hervorgehobenes Profil
# Location in city: Digitale Bewerbermappe
# Location street: Werbefrei & mehr
# Price: N/A
# Size: N/A
# Available from: N/A
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: N/A
#
# Listing #13:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 14
# Price: 895 €
# Size: 24 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #14:
# Title: 1 Zimmer Wohnung in Kreuzberg / Bergmannkiez: Zwischenmiete April bis Juni 2025
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Kreuzberg
# Location street: Nostitzstraße
# Price: 700 €
# Size: 33 m²
# Available from: 10.04.2025
#
#
# Available to: 30.06.2025
# Advertisement time (minutes ago): 0
# Provider: Herr Farahani
#
# Listing #15:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 13
# Price: 895 €
# Size: 14 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #16:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 14
# Price: 895 €
# Size: 48 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #17:
# Title: 1 Schlafzimmer Wohnung/1-Zimmer Wohnung in herrlicher Nachbarschaft - Von 01.05.25 bis 31.05.25
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Prenzlauer Berg
# Location street: Stavangerstraße 2
# Price: 950 €
# Size: 40 m²
# Available from: 01.05.2025
#
#
# Available to: 31.05.2025
# Advertisement time (minutes ago): 0
# Provider: Jiri
#
# Listing #18:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 15
# Price: 895 €
# Size: 26 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #19:
# Title: Studio nahe Tempelhofer Feld
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Tempelhof
# Location street: Nackenheimer Weg 2
# Price: 835 €
# Size: 30 m²
# Available from: 15.04.2025
#
#
# Available to: 05.05.2025
# Advertisement time (minutes ago): 0
# Provider: Simon
#
# Listing #20:
# Title: noch nichts gefunden? Dann  Haus + 40 mins pendeln mit RE5 nach Berlin!
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Gransee
# Location street: Menzer Straße
# Price: 680 €
# Size: 40 m²
# Available from: 06.04.2025
#
#
# Available to: 30.09.2025
# Advertisement time (minutes ago): 0
# Provider: Robert
#
# Listing #21:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Mitte
# Location street: Fischerinsel 15
# Price: 895 €
# Size: 50 m²
# Available from: 06.04.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: STACEY (Verified company)
#
# Listing #22:
# Title: Schönes 1-Zimmer-Appartment für 1 Jahr
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Lichtenberg
# Location street: Paul-Junius-Straße
# Price: 650 €
# Size: 35 m²
# Available from: 01.05.2025
#
#
# Available to: 30.04.2026
# Advertisement time (minutes ago): 0
# Provider: Leonie Neef
#
# Listing #23:
# Title: Privates Zimmer mit Balkon ''M' - Airbnb-Quality Stay!
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Treptow
# Location street: Bergaustraße
# Price: 600 €
# Size: 27 m²
# Available from: 06.04.2025
#
#
# Available to: 31.12.2025
# Advertisement time (minutes ago): 0
# Provider: M. Bakri
#
# Listing #24:
# Title: Privatzimmer mit Balkon ''N' - Airbnb-Quality Stay!
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
#
#                             Treptow
# Location street: Bergaustraße
# Price: 25 €
# Size: 27 m²
# Available from: 06.04.2025
#
#
# Available to: 31.12.2025
# Advertisement time (minutes ago): 0
# Provider: M. Bakri
#
# Listing #25:
# Title: Eine wunderschöne luxuriöse 1,5 Zimmer Dachgeschoßwohnung
# Status: 1-Zimmer-Wohnung
# Location in city: Berlin
# Location street: Dahnstraße
# Price: 1200 €
# Size: 32 m²
# Available from: 01.07.2025
# Available to: N/A
# Advertisement time (minutes ago): 0
# Provider: Wunderflats GmbH (Verified company)

# %%
#a better model to save data into sql 
import sqlite3
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import os
import time

def create_database():
    """Create the database and table if they don't exist"""
    conn = sqlite3.connect('webscrapping_results/house_and_price.db')
    c = conn.cursor()
    
    c.execute('''CREATE TABLE IF NOT EXISTS listings
                 (id INTEGER PRIMARY KEY AUTOINCREMENT,
                  title TEXT,
                  status TEXT,
                  location_in_city TEXT,
                  location_street TEXT,
                  price TEXT,
                  size TEXT,
                  duration_from TEXT,
                  duration_to TEXT,
                  advertisement_time_minutes INTEGER,
                  provider TEXT,
                  is_verified_company INTEGER,
                  scrape_timestamp TEXT)''')
    
    conn.commit()
    conn.close()

def scrape_listings():
    """Scrape listings from WG-Gesucht website"""
    url = "https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Berlin.8.1.1.0.html"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    listings = []
    
    # Find all listing cards
    cards = soup.find_all('div', class_='card_body')
    
    for card in cards:
        try:
            # Extract title
            title_tag = card.find('h3', class_='truncate_title')
            title = title_tag.get_text(strip=True) if title_tag else "N/A"
            
            # Extract status and location info
            status_location = card.find('div', class_='col-xs-11').get_text(strip=True) if card.find('div', class_='col-xs-11') else "N/A"
            parts = [part.strip() for part in status_location.split('|')]
            
            status = parts[0] if len(parts) > 0 else "N/A"
            location_in_city = parts[1] if len(parts) > 1 else "N/A"
            location_street = parts[2] if len(parts) > 2 else "N/A"
            
            # Extract price, dates, and size
            middle_row = card.find('div', class_='middle')
            if middle_row:
                cols = middle_row.find_all('div', class_='col-xs-3') + middle_row.find_all('div', class_='col-xs-5')
                price = cols[0].get_text(strip=True) if len(cols) > 0 else "N/A"
                dates = cols[1].get_text(strip=True) if len(cols) > 1 else "N/A"
                size = cols[2].get_text(strip=True) if len(cols) > 2 else "N/A"
                
                # Split dates into from and to
                if " - " in dates:
                    duration_from, duration_to = dates.split(" - ")
                else:
                    duration_from = dates
                    duration_to = "N/A"
            else:
                price = "N/A"
                size = "N/A"
                duration_from = "N/A"
                duration_to = "N/A"
            
            # Extract provider info and online time
            bottom_row = card.find('div', class_='bottom')
            if bottom_row:
                # Provider name
                provider_span = bottom_row.find('span', class_='ml5')
                provider = provider_span.get_text(strip=True) if provider_span else "N/A"
                
                # Check if verified company
                verified_tag = bottom_row.find('a', class_='label_verified')
                is_verified_company = 1 if verified_tag else 0
                
                # Online time
                online_span = bottom_row.find('span', style='color: #218700;')
                online_text = online_span.get_text(strip=True) if online_span else "N/A"
                
                # Calculate minutes since advertisement
                if "minute" in online_text.lower():
                    minutes = int(''.join(filter(str.isdigit, online_text)))
                elif "hour" in online_text.lower():
                    hours = int(''.join(filter(str.isdigit, online_text)))
                    minutes = hours * 60
                elif "currently" in online_text.lower() or "online" in online_text.lower():
                    minutes = 0
                else:
                    minutes = -1  # Unknown format
            else:
                provider = "N/A"
                is_verified_company = 0
                minutes = -1
            
            # Current timestamp for when we scraped this data
            scrape_timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            
            listings.append({
                'title': title,
                'status': status,
                'location_in_city': location_in_city,
                'location_street': location_street,
                'price': price,
                'size': size,
                'duration_from': duration_from,
                'duration_to': duration_to,
                'advertisement_time_minutes': minutes,
                'provider': provider,
                'is_verified_company': is_verified_company,
                'scrape_timestamp': scrape_timestamp
            })
            
        except Exception as e:
            print(f"Error processing a listing: {e}")
            continue
    
    return listings

def save_to_database(listings):
    """Save scraped listings to the database"""
    conn = sqlite3.connect('webscrapping_results/house_and_price.db')
    c = conn.cursor()
    
    for listing in listings:
        # Check if this listing already exists (based on title, provider, and price)
        c.execute('''SELECT id FROM listings 
                     WHERE title = ? AND provider = ? AND price = ?''',
                 (listing['title'], listing['provider'], listing['price']))
        
        if not c.fetchone():  # Only insert if it's not already in the database
            c.execute('''INSERT INTO listings 
                         (title, status, location_in_city, location_street, price, size, 
                          duration_from, duration_to, advertisement_time_minutes, 
                          provider, is_verified_company, scrape_timestamp)
                         VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''',
                     (listing['title'], listing['status'], listing['location_in_city'],
                      listing['location_street'], listing['price'], listing['size'],
                      listing['duration_from'], listing['duration_to'], 
                      listing['advertisement_time_minutes'], listing['provider'],
                      listing['is_verified_company'], listing['scrape_timestamp']))
    
    conn.commit()
    conn.close()

def print_listings(listings):
    """Print the scraped listings for verification"""
    print("\nScraped Listings:")
    print("-" * 100)
    for i, listing in enumerate(listings, 1):
        print(f"Listing {i}:")
        print(f"Title: {listing['title']}")
        print(f"Status: {listing['status']}")
        print(f"Location in City: {listing['location_in_city']}")
        print(f"Location Street: {listing['location_street']}")
        print(f"Price: {listing['price']}")
        print(f"Size: {listing['size']}")
        print(f"Available From: {listing['duration_from']}")
        print(f"Available To: {listing['duration_to']}")
        print(f"Advertisement Time (minutes ago): {listing['advertisement_time_minutes']}")
        print(f"Provider: {listing['provider']}")
        print(f"Verified Company: {'Yes' if listing['is_verified_company'] else 'No'}")
        print(f"Scraped At: {listing['scrape_timestamp']}")
        print("-" * 100)

def main():
    # Create directory if it doesn't exist
    os.makedirs('webscrapping_results', exist_ok=True)
    
    # Create database if it doesn't exist
    create_database()
    
    # Scrape listings
    print("Scraping listings from WG-Gesucht...")
    listings = scrape_listings()
    
    if listings:
        # Print the scraped data
        print_listings(listings)
        
        # Save to database
        save_to_database(listings)
        print(f"\nSuccessfully saved {len(listings)} listings to the database.")
    else:
        print("No listings were scraped.")

if __name__ == "__main__":
    main()
# Out:
# Scraping listings from WG-Gesucht...
#
# Scraped Listings:
# ----------------------------------------------------------------------------------------------------
# Listing 1:
# Title: Charmantes und helles 1-Zimmer-Apartment in beliebtem Viertel, für Singles oder Paare
# Status: N/A
# Location in City: N/A
# Location Street: N/A
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 2:
# Title: Tolles Studio-Apartment im Studentenwohnheim zu vermieten
# Status: N/A
# Location in City: N/A
# Location Street: N/A
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 3:
# Title: einzimmerwohnung
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Friedrichshain
# Location Street: Mühlenstraße61-64
# Price: 500 €
# Size: 06.04.2025
#
#                                             - 24.06.2027
# Available From: 47 m²
# Available To: N/A
# Advertisement Time (minutes ago): 3
# Provider: Felix Leon
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 4:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 07.04.2025
# Available From: 46 m²
# Available To: N/A
# Advertisement Time (minutes ago): 10
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 5:
# Title: UNTERMIETER*IN gesucht: 54qm Wohnung im Kollwitzkiez, Prenzlauer Berg, Berlin
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Prenzlauer Berg
# Location Street: Kollwitzstraße
# Price: 1200 €
# Size: 01.05.2025
#
#                                             - 30.11.2025
# Available From: 54 m²
# Available To: N/A
# Advertisement Time (minutes ago): 13
# Provider: Joanna C.
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 6:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 07.04.2025
# Available From: 16 m²
# Available To: N/A
# Advertisement Time (minutes ago): 19
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 7:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 06.04.2025
# Available From: 45 m²
# Available To: N/A
# Advertisement Time (minutes ago): 36
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 8:
# Title: 30 qm Studio in Shoneweide - NUR im Dezember
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Bohnsdorf
# Location Street: Fließstraße
# Price: 600 €
# Size: 09.08.2024
# Available From: 30 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Wunderflats GmbH
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 9:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 06.04.2025
# Available From: 45 m²
# Available To: N/A
# Advertisement Time (minutes ago): 52
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 10:
# Title: STACEY Apartments Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 06.04.2025
# Available From: 36 m²
# Available To: N/A
# Advertisement Time (minutes ago): 57
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 11:
# Title: Sonniges Studio mit privater Terrasse direkt am Mauerpark – zentral & möbliert im Studio House Berlin
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Gesundbrunnen
# Location Street: Bärbel-Bohley-Ring 26
# Price: 990 €
# Size: 07.04.2025
#
#                                             - 31.03.2027
# Available From: 23 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Frau Gomez
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 12:
# Title: Zugriff auf alle Anzeigen mit WG-Gesucht+
# Status: Hervorgehobenes Profil
# Location in City: Digitale Bewerbermappe
# Location Street: Werbefrei & mehr
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 13:
# Title: Moderner Komfort trifft künstlerischen Charme – stilvolle 1-Zimmer-Wohnung mit Altbau Flair in Prenzlauer Berg
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Seelower Stra?e 10439 Berlin
# Location Street: Krossener Straße
# Price: 1200 €
# Size: 07.04.2025
# Available From: 36 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Sherry Mclemore
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 14:
# Title: Großes 1-Zimmer-Küche-Bad Souterrain Apartment in Kleinmachnow
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Kleinmachnow
# Location Street: Grasweg
# Price: 690 €
# Size: 16.04.2025
# Available From: 55 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Frau Huang
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 15:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 06.04.2025
# Available From: 26 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 16:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 06.04.2025
# Available From: 24 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 17:
# Title: 1 Zimmer Wohnung in Kreuzberg / Bergmannkiez: Zwischenmiete April bis Juni 2025
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Kreuzberg
# Location Street: Nostitzstraße
# Price: 700 €
# Size: 10.04.2025
#
#                                             - 30.06.2025
# Available From: 33 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Herr Farahani
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 18:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 06.04.2025
# Available From: 14 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 19:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 06.04.2025
# Available From: 48 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 20:
# Title: 1 Schlafzimmer Wohnung/1-Zimmer Wohnung in herrlicher Nachbarschaft - Von 01.05.25 bis 31.05.25
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Prenzlauer Berg
# Location Street: Stavangerstraße 2
# Price: 950 €
# Size: 01.05.2025
#
#                                             - 31.05.2025
# Available From: 40 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Jiri
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 21:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 06.04.2025
# Available From: 26 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 22:
# Title: Studio nahe Tempelhofer Feld
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Tempelhof
# Location Street: Nackenheimer Weg 2
# Price: 835 €
# Size: 15.04.2025
#
#                                             - 05.05.2025
# Available From: 30 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Simon
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 23:
# Title: noch nichts gefunden? Dann  Haus + 40 mins pendeln mit RE5 nach Berlin!
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Gransee
# Location Street: Menzer Straße
# Price: 680 €
# Size: 06.04.2025
#
#                                             - 30.09.2025
# Available From: 40 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Robert
# Verified Company: No
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 24:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 06.04.2025
# Available From: 50 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
# Listing 25:
# Title: Schickes Zimmer im Berliner Bezirk Pankow
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Pankow
# Location Street: Mühlenstraße
# Price: 999 €
# Size: 01.06.2025
# Available From: 120 m²
# Available To: N/A
# Advertisement Time (minutes ago): 0
# Provider: Wunderflats GmbH
# Verified Company: Yes
# Scraped At: 2025-04-07 00:16:59
# ----------------------------------------------------------------------------------------------------
#
# Successfully saved 25 listings to the database.

# %%
#after checking the issue of some minor errors over the data
import sqlite3
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import os
import re

def create_database():
    """Create the database and table if they don't exist"""
    conn = sqlite3.connect('webscrapping_results/house_and_price.db')
    c = conn.cursor()
    
    c.execute('''CREATE TABLE IF NOT EXISTS listings
                 (id INTEGER PRIMARY KEY AUTOINCREMENT,
                  title TEXT,
                  status TEXT,
                  location_in_city TEXT,
                  location_street TEXT,
                  price TEXT,
                  size TEXT,
                  duration_from TEXT,
                  duration_to TEXT,
                  advertisement_time_minutes INTEGER,
                  provider TEXT,
                  is_verified_company INTEGER,
                  scrape_timestamp TEXT)''')
    
    conn.commit()
    conn.close()

def extract_price_size_dates(middle_row):
    """Extract price, size, and dates from the middle row with better format handling"""
    price = "N/A"
    size = "N/A"
    duration_from = "N/A"
    duration_to = "N/A"
    
    if not middle_row:
        return price, size, duration_from, duration_to
    
    # Get all columns in the middle row
    cols = middle_row.find_all('div', recursive=False)
    
    # Typically there are 3 columns: price, dates, size
    if len(cols) >= 3:
        price = cols[0].get_text(strip=True)
        dates = cols[1].get_text(strip=True)
        size = cols[2].get_text(strip=True)
        
        # Handle cases where size and dates might be swapped
        if 'm²' in dates or any(c.isdigit() for c in dates.split()[0] if dates.split()):
            # Dates and size are swapped
            size, dates = dates, size
        
        # Split dates into from and to
        if " - " in dates:
            duration_from, duration_to = dates.split(" - ")
        else:
            duration_from = dates
            duration_to = "N/A"
    
    return price, size, duration_from, duration_to

def parse_online_time(online_text):
    """Parse the online time text into minutes"""
    if not online_text or online_text == "N/A":
        return -1
    
    online_text = online_text.lower()
    
    # Extract numbers from the text
    numbers = re.findall(r'\d+', online_text)
    if not numbers:
        return 0 if any(word in online_text for word in ['jetzt', 'online', 'current']) else -1
    
    num = int(numbers[0])
    
    if 'minute' in online_text:
        return num
    elif 'hour' in online_text or 'stunde' in online_text:
        return num * 60
    elif 'day' in online_text or 'tag' in online_text:
        return num * 1440
    else:
        return 0 if 'online' in online_text else -1

def scrape_listings():
    """Scrape listings from WG-Gesucht website"""
    url = "https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Berlin.8.1.1.0.html"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    listings = []
    
    # Find all listing cards
    cards = soup.find_all('div', class_='card_body')
    
    for card in cards:
        try:
            # Extract title
            title_tag = card.find('h3', class_='truncate_title')
            title = title_tag.get_text(strip=True) if title_tag else "N/A"
            
            # Extract status and location info
            status_location = card.find('div', class_='col-xs-11').get_text(strip=True) if card.find('div', class_='col-xs-11') else "N/A"
            parts = [part.strip() for part in status_location.split('|') if part.strip()]
            
            status = parts[0] if len(parts) > 0 else "N/A"
            location_in_city = parts[1] if len(parts) > 1 else "N/A"
            location_street = parts[2] if len(parts) > 2 else "N/A"
            
            # Extract price, size, and dates with improved parsing
            middle_row = card.find('div', class_='middle')
            price, size, duration_from, duration_to = extract_price_size_dates(middle_row)
            
            # Clean up size (remove any non-size text)
            if size != "N/A":
                size = ''.join([c for c in size if c.isdigit() or c in ['.', ',']])
                if ',' in size:
                    size = size.replace(',', '.')
                size = f"{size} m²"
            
            # Extract provider info and online time
            bottom_row = card.find('div', class_='bottom')
            if bottom_row:
                # Provider name
                provider_span = bottom_row.find('span', class_='ml5')
                provider = provider_span.get_text(strip=True) if provider_span else "N/A"
                
                # Check if verified company
                verified_tag = bottom_row.find('a', class_='label_verified')
                is_verified_company = 1 if verified_tag else 0
                
                # Online time
                online_span = bottom_row.find('span', style='color: #218700;') or \
                              bottom_row.find('span', class_='online_status')
                online_text = online_span.get_text(strip=True) if online_span else "N/A"
                minutes = parse_online_time(online_text)
            else:
                provider = "N/A"
                is_verified_company = 0
                minutes = -1
            
            # Current timestamp for when we scraped this data
            scrape_timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            
            listings.append({
                'title': title,
                'status': status,
                'location_in_city': location_in_city,
                'location_street': location_street,
                'price': price,
                'size': size,
                'duration_from': duration_from,
                'duration_to': duration_to,
                'advertisement_time_minutes': minutes,
                'provider': provider,
                'is_verified_company': is_verified_company,
                'scrape_timestamp': scrape_timestamp
            })
            
        except Exception as e:
            print(f"Error processing a listing: {e}")
            continue
    
    return listings

def save_to_database(listings):
    """Save scraped listings to the database"""
    conn = sqlite3.connect('webscrapping_results/house_and_price.db')
    c = conn.cursor()
    
    for listing in listings:
        # Check if this listing already exists (based on title, provider, and price)
        c.execute('''SELECT id FROM listings 
                     WHERE title = ? AND provider = ? AND price = ?''',
                 (listing['title'], listing['provider'], listing['price']))
        
        if not c.fetchone():  # Only insert if it's not already in the database
            c.execute('''INSERT INTO listings 
                         (title, status, location_in_city, location_street, price, size, 
                          duration_from, duration_to, advertisement_time_minutes, 
                          provider, is_verified_company, scrape_timestamp)
                         VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''',
                     (listing['title'], listing['status'], listing['location_in_city'],
                      listing['location_street'], listing['price'], listing['size'],
                      listing['duration_from'], listing['duration_to'], 
                      listing['advertisement_time_minutes'], listing['provider'],
                      listing['is_verified_company'], listing['scrape_timestamp']))
    
    conn.commit()
    conn.close()

def print_listings(listings):
    """Print the scraped listings for verification"""
    print("\nScraped Listings:")
    print("-" * 100)
    for i, listing in enumerate(listings, 1):
        print(f"Listing {i}:")
        print(f"Title: {listing['title']}")
        print(f"Status: {listing['status']}")
        print(f"Location in City: {listing['location_in_city']}")
        print(f"Location Street: {listing['location_street']}")
        print(f"Price: {listing['price']}")
        print(f"Size: {listing['size']}")
        print(f"Available From: {listing['duration_from']}")
        print(f"Available To: {listing['duration_to']}")
        print(f"Advertisement Time (minutes ago): {listing['advertisement_time_minutes']}")
        print(f"Provider: {listing['provider']}")
        print(f"Verified Company: {'Yes' if listing['is_verified_company'] else 'No'}")
        print(f"Scraped At: {listing['scrape_timestamp']}")
        print("-" * 100)

def main():
    # Create directory if it doesn't exist
    os.makedirs('webscrapping_results', exist_ok=True)
    
    # Create database if it doesn't exist
    create_database()
    
    # Scrape listings
    print("Scraping listings from WG-Gesucht...")
    listings = scrape_listings()
    
    if listings:
        # Print the scraped data
        print_listings(listings)
        
        # Save to database
        save_to_database(listings)
        print(f"\nSuccessfully saved {len(listings)} listings to the database.")
    else:
        print("No listings were scraped.")

if __name__ == "__main__":
    main()
# Out:
# Scraping listings from WG-Gesucht...
#
# Scraped Listings:
# ----------------------------------------------------------------------------------------------------
# Listing 1:
# Title: Modern designtes Studio-Apartment zu vermieten - Internationals welcome
# Status: N/A
# Location in City: N/A
# Location Street: N/A
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 2:
# Title: Sonnige 1-Zimmer-Wohnung in zentraler Lage zu vermieten
# Status: N/A
# Location in City: N/A
# Location Street: N/A
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 3:
# Title: Ein Zimmer apt
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Biesdorf
# Location Street: Oberfeldstraße
# Price: 340 €
# Size: 10.04.202506.05.2025 m²
# Available From: 18 m²
# Available To: N/A
# Advertisement Time (minutes ago): 3
# Provider: Geni
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 4:
# Title: einzimmerwohnung
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Friedrichshain
# Location Street: Mühlenstraße61-64
# Price: 500 €
# Size: 06.04.202524.06.2027 m²
# Available From: 47 m²
# Available To: N/A
# Advertisement Time (minutes ago): 9
# Provider: Felix Leon
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 5:
# Title: [STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 07.04.2025 m²
# Available From: 44 m²
# Available To: N/A
# Advertisement Time (minutes ago): 12
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 6:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 07.04.2025 m²
# Available From: 46 m²
# Available To: N/A
# Advertisement Time (minutes ago): 17
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 7:
# Title: UNTERMIETER*IN gesucht: 54qm Wohnung im Kollwitzkiez, Prenzlauer Berg, Berlin
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Prenzlauer Berg
# Location Street: Kollwitzstraße
# Price: 1200 €
# Size: 01.05.202530.11.2025 m²
# Available From: 54 m²
# Available To: N/A
# Advertisement Time (minutes ago): 19
# Provider: Joanna C.
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 8:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 07.04.2025 m²
# Available From: 16 m²
# Available To: N/A
# Advertisement Time (minutes ago): 26
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 9:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 06.04.2025 m²
# Available From: 45 m²
# Available To: N/A
# Advertisement Time (minutes ago): 43
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 10:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 06.04.2025 m²
# Available From: 45 m²
# Available To: N/A
# Advertisement Time (minutes ago): 59
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 11:
# Title: Zugriff auf alle Anzeigen mit WG-Gesucht+
# Status: Hervorgehobenes Profil
# Location in City: Digitale Bewerbermappe
# Location Street: Werbefrei & mehr
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 12:
# Title: STACEY Apartments Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 06.04.2025 m²
# Available From: 36 m²
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 13:
# Title: Sonniges Studio mit privater Terrasse direkt am Mauerpark – zentral & möbliert im Studio House Berlin
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Gesundbrunnen
# Location Street: Bärbel-Bohley-Ring 26
# Price: 990 €
# Size: 07.04.202531.03.2027 m²
# Available From: 23 m²
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: Frau Gomez
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 14:
# Title: 30 qm Studio in Shoneweide - NUR im Dezember
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Bohnsdorf
# Location Street: Fließstraße
# Price: 600 €
# Size: 09.08.2024 m²
# Available From: 30 m²
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: Wunderflats GmbH
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 15:
# Title: Moderner Komfort trifft künstlerischen Charme – stilvolle 1-Zimmer-Wohnung mit Altbau Flair in Prenzlauer Berg
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Seelower Stra?e 10439 Berlin
# Location Street: Krossener Straße
# Price: 1200 €
# Size: 07.04.2025 m²
# Available From: 36 m²
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: Sherry Mclemore
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 16:
# Title: Großes 1-Zimmer-Küche-Bad Souterrain Apartment in Kleinmachnow
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Kleinmachnow
# Location Street: Grasweg
# Price: 690 €
# Size: 16.04.2025 m²
# Available From: 55 m²
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: Frau Huang
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 17:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 06.04.2025 m²
# Available From: 26 m²
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 18:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 06.04.2025 m²
# Available From: 24 m²
# Available To: N/A
# Advertisement Time (minutes ago): 120
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 19:
# Title: 1 Zimmer Wohnung in Kreuzberg / Bergmannkiez: Zwischenmiete April bis Juni 2025
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Kreuzberg
# Location Street: Nostitzstraße
# Price: 700 €
# Size: 10.04.202530.06.2025 m²
# Available From: 33 m²
# Available To: N/A
# Advertisement Time (minutes ago): 120
# Provider: Herr Farahani
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 20:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 06.04.2025 m²
# Available From: 14 m²
# Available To: N/A
# Advertisement Time (minutes ago): 120
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 21:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 06.04.2025 m²
# Available From: 48 m²
# Available To: N/A
# Advertisement Time (minutes ago): 120
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 22:
# Title: 1 Schlafzimmer Wohnung/1-Zimmer Wohnung in herrlicher Nachbarschaft - Von 01.05.25 bis 31.05.25
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Prenzlauer Berg
# Location Street: Stavangerstraße 2
# Price: 950 €
# Size: 01.05.202531.05.2025 m²
# Available From: 40 m²
# Available To: N/A
# Advertisement Time (minutes ago): 120
# Provider: Jiri
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 23:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 06.04.2025 m²
# Available From: 26 m²
# Available To: N/A
# Advertisement Time (minutes ago): 180
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 24:
# Title: Studio nahe Tempelhofer Feld
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Tempelhof
# Location Street: Nackenheimer Weg 2
# Price: 835 €
# Size: 15.04.202505.05.2025 m²
# Available From: 30 m²
# Available To: N/A
# Advertisement Time (minutes ago): 180
# Provider: Simon
# Verified Company: No
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
# Listing 25:
# Title: Geräumiges Zimmer in Berlin Kreuzberg
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Neukölln
# Location Street: Emser Straße
# Price: 999 €
# Size: 01.06.2025 m²
# Available From: 25 m²
# Available To: N/A
# Advertisement Time (minutes ago): 960
# Provider: Wunderflats GmbH
# Verified Company: Yes
# Scraped At: 2025-04-07 00:23:19
# ----------------------------------------------------------------------------------------------------
#
# Successfully saved 25 listings to the database.

# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import os
import re

def create_database():
    """Create the database and table if they don't exist"""
    conn = sqlite3.connect('webscrapping_results/house_and_price.db')
    c = conn.cursor()
    
    c.execute('''CREATE TABLE IF NOT EXISTS listings
                 (id INTEGER PRIMARY KEY AUTOINCREMENT,
                  title TEXT,
                  status TEXT,
                  location_in_city TEXT,
                  location_street TEXT,
                  price TEXT,
                  size TEXT,
                  duration_from TEXT,
                  duration_to TEXT,
                  advertisement_time_minutes INTEGER,
                  provider TEXT,
                  is_verified_company INTEGER,
                  scrape_timestamp TEXT)''')
    
    conn.commit()
    conn.close()

def is_date(text):
    """Check if text matches DD.MM.YYYY date format"""
    return bool(re.match(r'\d{2}\.\d{2}\.\d{4}', text))

def is_size(text):
    """Check if text contains m² or is a number that likely represents size"""
    return 'm²' in text or (text.replace('.', '').isdigit() and float(text) < 200)

def extract_price_size_dates(middle_row):
    """Extract price, size, and dates from the middle row with precise format handling"""
    price = "N/A"
    size = "N/A"
    duration_from = "N/A"
    duration_to = "N/A"
    
    if not middle_row:
        return price, size, duration_from, duration_to
    
    # Get all columns in the middle row
    cols = middle_row.find_all('div', recursive=False)
    
    if len(cols) >= 3:
        price = cols[0].get_text(strip=True)
        
        # Process the middle and right columns
        middle_text = cols[1].get_text(strip=True)
        right_text = cols[2].get_text(strip=True)
        
        # Identify which is dates and which is size
        if is_date(middle_text) or ('-' in middle_text and any(is_date(p) for p in middle_text.split('-'))):
            # Middle column contains dates
            dates = middle_text
            size_candidate = right_text
        elif is_date(right_text) or ('-' in right_text and any(is_date(p) for p in right_text.split('-'))):
            # Right column contains dates
            dates = right_text
            size_candidate = middle_text
        else:
            # Fallback - assume middle is dates, right is size
            dates = middle_text
            size_candidate = right_text
        
        # Extract size
        size_match = re.search(r'(\d+[\.,]?\d*)\s*m²?', size_candidate, re.IGNORECASE)
        if size_match:
            size = size_match.group(1).replace(',', '.') + " m²"
        else:
            size = "N/A"
        
        # Extract dates
        if '-' in dates:
            date_parts = [p.strip() for p in dates.split('-') if p.strip()]
            if len(date_parts) == 2:
                duration_from, duration_to = date_parts
            else:
                duration_from = dates
                duration_to = "N/A"
        else:
            duration_from = dates
            duration_to = "N/A"
    
    return price, size, duration_from, duration_to

def parse_online_time(online_text):
    """Parse the online time text into minutes"""
    if not online_text or online_text == "N/A":
        return -1
    
    online_text = online_text.lower()
    
    # Extract numbers from the text
    numbers = re.findall(r'\d+', online_text)
    if not numbers:
        return 0 if any(word in online_text for word in ['jetzt', 'online', 'current']) else -1
    
    num = int(numbers[0])
    
    if 'minute' in online_text:
        return num
    elif 'hour' in online_text or 'stunde' in online_text:
        return num * 60
    elif 'day' in online_text or 'tag' in online_text:
        return num * 1440
    else:
        return 0 if 'online' in online_text else -1

def scrape_listings():
    """Scrape listings from WG-Gesucht website"""
    url = "https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Berlin.8.1.1.0.html"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    listings = []
    
    # Find all listing cards
    cards = soup.find_all('div', class_='card_body')
    
    for card in cards:
        try:
            # Extract title
            title_tag = card.find('h3', class_='truncate_title')
            title = title_tag.get_text(strip=True) if title_tag else "N/A"
            
            # Extract status and location info
            status_location = card.find('div', class_='col-xs-11').get_text(strip=True) if card.find('div', class_='col-xs-11') else "N/A"
            parts = [part.strip() for part in status_location.split('|') if part.strip()]
            
            status = parts[0] if len(parts) > 0 else "N/A"
            location_in_city = parts[1] if len(parts) > 1 else "N/A"
            location_street = parts[2] if len(parts) > 2 else "N/A"
            
            # Extract price, size, and dates with improved parsing
            middle_row = card.find('div', class_='middle')
            price, size, duration_from, duration_to = extract_price_size_dates(middle_row)
            
            # Clean up location street (remove line breaks and extra spaces)
            location_street = ' '.join(location_street.split())
            
            # Extract provider info and online time
            bottom_row = card.find('div', class_='bottom')
            if bottom_row:
                # Provider name
                provider_span = bottom_row.find('span', class_='ml5')
                provider = provider_span.get_text(strip=True) if provider_span else "N/A"
                
                # Check if verified company
                verified_tag = bottom_row.find('a', class_='label_verified')
                is_verified_company = 1 if verified_tag else 0
                
                # Online time
                online_span = bottom_row.find('span', style='color: #218700;') or \
                              bottom_row.find('span', class_='online_status')
                online_text = online_span.get_text(strip=True) if online_span else "N/A"
                minutes = parse_online_time(online_text)
            else:
                provider = "N/A"
                is_verified_company = 0
                minutes = -1
            
            # Current timestamp for when we scraped this data
            scrape_timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            
            # Debug print for verification
            print("\nRaw Data:")
            print(f"Middle Row: {middle_row.get_text(strip=True) if middle_row else 'N/A'}")
            print(f"Price: {price}")
            print(f"Size Candidate: {size}")
            print(f"Dates Candidate: {duration_from} - {duration_to}")
            
            listings.append({
                'title': title,
                'status': status,
                'location_in_city': location_in_city,
                'location_street': location_street,
                'price': price,
                'size': size,
                'duration_from': duration_from,
                'duration_to': duration_to,
                'advertisement_time_minutes': minutes,
                'provider': provider,
                'is_verified_company': is_verified_company,
                'scrape_timestamp': scrape_timestamp
            })
            
        except Exception as e:
            print(f"Error processing a listing: {e}")
            continue
    
    return listings

def save_to_database(listings):
    """Save scraped listings to the database"""
    conn = sqlite3.connect('webscrapping_results/house_and_price.db')
    c = conn.cursor()
    
    for listing in listings:
        # Check if this listing already exists (based on title, provider, and price)
        c.execute('''SELECT id FROM listings 
                     WHERE title = ? AND provider = ? AND price = ?''',
                 (listing['title'], listing['provider'], listing['price']))
        
        if not c.fetchone():  # Only insert if it's not already in the database
            c.execute('''INSERT INTO listings 
                         (title, status, location_in_city, location_street, price, size, 
                          duration_from, duration_to, advertisement_time_minutes, 
                          provider, is_verified_company, scrape_timestamp)
                         VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''',
                     (listing['title'], listing['status'], listing['location_in_city'],
                      listing['location_street'], listing['price'], listing['size'],
                      listing['duration_from'], listing['duration_to'], 
                      listing['advertisement_time_minutes'], listing['provider'],
                      listing['is_verified_company'], listing['scrape_timestamp']))
    
    conn.commit()
    conn.close()

def print_listings(listings):
    """Print the scraped listings for verification"""
    print("\nFinal Processed Listings:")
    print("=" * 100)
    for i, listing in enumerate(listings, 1):
        print(f"\nListing {i}:")
        print(f"Title: {listing['title']}")
        print(f"Status: {listing['status']}")
        print(f"Location in City: {listing['location_in_city']}")
        print(f"Location Street: {listing['location_street']}")
        print(f"Price: {listing['price']}")
        print(f"Size: {listing['size']}")
        print(f"Available From: {listing['duration_from']}")
        print(f"Available To: {listing['duration_to']}")
        print(f"Advertisement Time (minutes ago): {listing['advertisement_time_minutes']}")
        print(f"Provider: {listing['provider']}")
        print(f"Verified Company: {'Yes' if listing['is_verified_company'] else 'No'}")
        print(f"Scraped At: {listing['scrape_timestamp']}")
        print("-" * 100)

def main():
    # Create directory if it doesn't exist
    os.makedirs('webscrapping_results', exist_ok=True)
    
    # Create database if it doesn't exist
    create_database()
    
    # Scrape listings
    print("Scraping listings from WG-Gesucht...")
    listings = scrape_listings()
    
    if listings:
        # Print the scraped data
        print_listings(listings)
        
        # Save to database
        save_to_database(listings)
        print(f"\nSuccessfully saved {len(listings)} listings to the database.")
    else:
        print("No listings were scraped.")

if __name__ == "__main__":
    main()
# Out:
# Scraping listings from WG-Gesucht...
#
# Raw Data:
# Middle Row: ab530 €sofort frei - auch monatsweise oder für kurze Zeit
# Price: N/A
# Size Candidate: N/A
# Dates Candidate: N/A - N/A
#
# Raw Data:
# Middle Row: ab580 €auch monatsweise
# Price: N/A
# Size Candidate: N/A
# Dates Candidate: N/A - N/A
#
# Raw Data:
# Middle Row: 340 €10.04.2025
#
#                                             - 06.05.202518 m²
# Price: 340 €
# Size Candidate: 18 m²
# Dates Candidate: 10.04.2025 - 06.05.2025
#
# Raw Data:
# Middle Row: 500 €06.04.2025
#
#                                             - 24.06.202747 m²
# Price: 500 €
# Size Candidate: 47 m²
# Dates Candidate: 06.04.2025 - 24.06.2027
#
# Raw Data:
# Middle Row: 895 €07.04.202544 m²
# Price: 895 €
# Size Candidate: 44 m²
# Dates Candidate: 07.04.2025 - N/A
#
# Raw Data:
# Middle Row: 895 €07.04.202546 m²
# Price: 895 €
# Size Candidate: 46 m²
# Dates Candidate: 07.04.2025 - N/A
#
# Raw Data:
# Middle Row: 1200 €01.05.2025
#
#                                             - 30.11.202554 m²
# Price: 1200 €
# Size Candidate: 54 m²
# Dates Candidate: 01.05.2025 - 30.11.2025
#
# Raw Data:
# Middle Row: 895 €07.04.202516 m²
# Price: 895 €
# Size Candidate: 16 m²
# Dates Candidate: 07.04.2025 - N/A
#
# Raw Data:
# Middle Row: 895 €06.04.202545 m²
# Price: 895 €
# Size Candidate: 45 m²
# Dates Candidate: 06.04.2025 - N/A
#
# Raw Data:
# Middle Row: 895 €06.04.202545 m²
# Price: 895 €
# Size Candidate: 45 m²
# Dates Candidate: 06.04.2025 - N/A
#
# Raw Data:
# Middle Row: N/A
# Price: N/A
# Size Candidate: N/A
# Dates Candidate: N/A - N/A
#
# Raw Data:
# Middle Row: 895 €06.04.202536 m²
# Price: 895 €
# Size Candidate: 36 m²
# Dates Candidate: 06.04.2025 - N/A
#
# Raw Data:
# Middle Row: 990 €07.04.2025
#
#                                             - 31.03.202723 m²
# Price: 990 €
# Size Candidate: 23 m²
# Dates Candidate: 07.04.2025 - 31.03.2027
#
# Raw Data:
# Middle Row: 600 €09.08.202430 m²
# Price: 600 €
# Size Candidate: 30 m²
# Dates Candidate: 09.08.2024 - N/A
#
# Raw Data:
# Middle Row: 1200 €07.04.202536 m²
# Price: 1200 €
# Size Candidate: 36 m²
# Dates Candidate: 07.04.2025 - N/A
#
# Raw Data:
# Middle Row: 690 €16.04.202555 m²
# Price: 690 €
# Size Candidate: 55 m²
# Dates Candidate: 16.04.2025 - N/A
#
# Raw Data:
# Middle Row: 895 €06.04.202526 m²
# Price: 895 €
# Size Candidate: 26 m²
# Dates Candidate: 06.04.2025 - N/A
#
# Raw Data:
# Middle Row: 895 €06.04.202524 m²
# Price: 895 €
# Size Candidate: 24 m²
# Dates Candidate: 06.04.2025 - N/A
#
# Raw Data:
# Middle Row: 700 €10.04.2025
#
#                                             - 30.06.202533 m²
# Price: 700 €
# Size Candidate: 33 m²
# Dates Candidate: 10.04.2025 - 30.06.2025
#
# Raw Data:
# Middle Row: 895 €06.04.202514 m²
# Price: 895 €
# Size Candidate: 14 m²
# Dates Candidate: 06.04.2025 - N/A
#
# Raw Data:
# Middle Row: 895 €06.04.202548 m²
# Price: 895 €
# Size Candidate: 48 m²
# Dates Candidate: 06.04.2025 - N/A
#
# Raw Data:
# Middle Row: 950 €01.05.2025
#
#                                             - 31.05.202540 m²
# Price: 950 €
# Size Candidate: 40 m²
# Dates Candidate: 01.05.2025 - 31.05.2025
#
# Raw Data:
# Middle Row: 895 €06.04.202526 m²
# Price: 895 €
# Size Candidate: 26 m²
# Dates Candidate: 06.04.2025 - N/A
#
# Raw Data:
# Middle Row: 835 €15.04.2025
#
#                                             - 05.05.202530 m²
# Price: 835 €
# Size Candidate: 30 m²
# Dates Candidate: 15.04.2025 - 05.05.2025
#
# Raw Data:
# Middle Row: 1200 €01.07.202532 m²
# Price: 1200 €
# Size Candidate: 32 m²
# Dates Candidate: 01.07.2025 - N/A
#
# Final Processed Listings:
# ====================================================================================================
#
# Listing 1:
# Title: Modern designtes Studio-Apartment zu vermieten - Internationals welcome
# Status: N/A
# Location in City: N/A
# Location Street: N/A
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 2:
# Title: Tolles Studio-Apartment im Studentenwohnheim zu vermieten
# Status: N/A
# Location in City: N/A
# Location Street: N/A
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 3:
# Title: Ein Zimmer apt
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Biesdorf
# Location Street: Oberfeldstraße
# Price: 340 €
# Size: 18 m²
# Available From: 10.04.2025
# Available To: 06.05.2025
# Advertisement Time (minutes ago): 21
# Provider: Geni
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 4:
# Title: einzimmerwohnung
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Friedrichshain
# Location Street: Mühlenstraße61-64
# Price: 500 €
# Size: 47 m²
# Available From: 06.04.2025
# Available To: 24.06.2027
# Advertisement Time (minutes ago): 27
# Provider: Felix Leon
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 5:
# Title: [STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 44 m²
# Available From: 07.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 30
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 6:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 46 m²
# Available From: 07.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 35
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 7:
# Title: UNTERMIETER*IN gesucht: 54qm Wohnung im Kollwitzkiez, Prenzlauer Berg, Berlin
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Prenzlauer Berg
# Location Street: Kollwitzstraße
# Price: 1200 €
# Size: 54 m²
# Available From: 01.05.2025
# Available To: 30.11.2025
# Advertisement Time (minutes ago): 37
# Provider: Joanna C.
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 8:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 16 m²
# Available From: 07.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 44
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 9:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 45 m²
# Available From: 06.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 10:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 45 m²
# Available From: 06.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 11:
# Title: Zugriff auf alle Anzeigen mit WG-Gesucht+
# Status: Hervorgehobenes Profil
# Location in City: Digitale Bewerbermappe
# Location Street: Werbefrei & mehr
# Price: N/A
# Size: N/A
# Available From: N/A
# Available To: N/A
# Advertisement Time (minutes ago): -1
# Provider: N/A
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 12:
# Title: STACEY Apartments Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 36 m²
# Available From: 06.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 13:
# Title: Sonniges Studio mit privater Terrasse direkt am Mauerpark – zentral & möbliert im Studio House Berlin
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Gesundbrunnen
# Location Street: Bärbel-Bohley-Ring 26
# Price: 990 €
# Size: 23 m²
# Available From: 07.04.2025
# Available To: 31.03.2027
# Advertisement Time (minutes ago): 60
# Provider: Frau Gomez
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 14:
# Title: 30 qm Studio in Shoneweide - NUR im Dezember
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Bohnsdorf
# Location Street: Fließstraße
# Price: 600 €
# Size: 30 m²
# Available From: 09.08.2024
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: Wunderflats GmbH
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 15:
# Title: Moderner Komfort trifft künstlerischen Charme – stilvolle 1-Zimmer-Wohnung mit Altbau Flair in Prenzlauer Berg
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Seelower Stra?e 10439 Berlin
# Location Street: Krossener Straße
# Price: 1200 €
# Size: 36 m²
# Available From: 07.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: Sherry Mclemore
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 16:
# Title: Großes 1-Zimmer-Küche-Bad Souterrain Apartment in Kleinmachnow
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Kleinmachnow
# Location Street: Grasweg
# Price: 690 €
# Size: 55 m²
# Available From: 16.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 60
# Provider: Frau Huang
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 17:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 26 m²
# Available From: 06.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 120
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 18:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 24 m²
# Available From: 06.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 120
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 19:
# Title: 1 Zimmer Wohnung in Kreuzberg / Bergmannkiez: Zwischenmiete April bis Juni 2025
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Kreuzberg
# Location Street: Nostitzstraße
# Price: 700 €
# Size: 33 m²
# Available From: 10.04.2025
# Available To: 30.06.2025
# Advertisement Time (minutes ago): 120
# Provider: Herr Farahani
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 20:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 13
# Price: 895 €
# Size: 14 m²
# Available From: 06.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 120
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 21:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 14
# Price: 895 €
# Size: 48 m²
# Available From: 06.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 180
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 22:
# Title: 1 Schlafzimmer Wohnung/1-Zimmer Wohnung in herrlicher Nachbarschaft - Von 01.05.25 bis 31.05.25
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Prenzlauer Berg
# Location Street: Stavangerstraße 2
# Price: 950 €
# Size: 40 m²
# Available From: 01.05.2025
# Available To: 31.05.2025
# Advertisement Time (minutes ago): 180
# Provider: Jiri
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 23:
# Title: STACEY Coliving Mitte | www.stacey.de
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Mitte
# Location Street: Fischerinsel 15
# Price: 895 €
# Size: 26 m²
# Available From: 06.04.2025
# Available To: N/A
# Advertisement Time (minutes ago): 180
# Provider: STACEY
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 24:
# Title: Studio nahe Tempelhofer Feld
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
#
#                             Tempelhof
# Location Street: Nackenheimer Weg 2
# Price: 835 €
# Size: 30 m²
# Available From: 15.04.2025
# Available To: 05.05.2025
# Advertisement Time (minutes ago): 180
# Provider: Simon
# Verified Company: No
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Listing 25:
# Title: Eine wunderschöne luxuriöse 1,5 Zimmer Dachgeschoßwohnung
# Status: 1-Zimmer-Wohnung
# Location in City: Berlin
# Location Street: Dahnstraße
# Price: 1200 €
# Size: 32 m²
# Available From: 01.07.2025
# Available To: N/A
# Advertisement Time (minutes ago): 960
# Provider: Wunderflats GmbH
# Verified Company: Yes
# Scraped At: 2025-04-07 00:41:14
# ----------------------------------------------------------------------------------------------------
#
# Successfully saved 25 listings to the database.
